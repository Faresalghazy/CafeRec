# %% [markdown]
# # Purpose

# %% [markdown]
# This notebook is intended as a submission for the IBM professional data science certificate, it is not an academic resource, nor is it a complete product.

# %% [markdown]
# # Introduction

# %% [markdown]
# You are in a new unfamiliar area, and looking to grab a coffee. Maybe you want to have a quiet chat, maybe you want to work, maybe you want to enjoy some good tunes; but how do you decide where to go?
# With the recommender model I propose, you simply input a location and distance range then you and are recommended one, and only one place to go to. This is great for indecisive people looking for something new to try

# %% [markdown]
# # Data gathering

# %% [markdown]
# Since the product is supposed to help users based on their location, age, gender, and what they are looking for, we would ideally ask the user for these details.
# For the purpose of this notebook however, let us have a persona of a 20 year old female, at the Dubai mall, looking for somewhere with good music within 500 meteres.

# %%
user_Location="Manhattan mall" 
user_Preference=("quiet")
user_Age=22
user_Range=500 #in meters.

# %% [markdown]
# ## Begin by finding the coordinates of the dubai mall, then finding all the cafes within the specified range

# %%
#First transform the location into coordinates
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="UCafe")
location = geolocator.geocode(user_Location)
coordinates = (location.latitude, location.longitude)
coordinates
# Out:
# (40.74915154999999, -73.98927991787946)

# %%
#Setup foursquare credentials
CLIENT_ID = 'insert your id here as a string' # your Foursquare ID
CLIENT_SECRET = 'insert your secret here as a string' # your Foursquare Secret
VERSION = '20200506'
LIMIT = 500

# %%
#Set up search query
search_query= 'Cafe,Coffee'
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, location.latitude, location.longitude, VERSION, search_query, user_Range, LIMIT)

# %%
#Search for results
import requests
results = requests.get(url).json()
#results

# %%
# assign relevant part of JSON to venues
import pandas
from pandas.io.json import json_normalize
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# c:\users\asus\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   import sys
#                          id                 name  \
# 0  5d03930e1c0b34002cd41e53       Le Cafe Coffee
# 1  4da4881522a5f04d67b03a55               Cafe R
# 2  4bf5663994af2d7f15a93b72  Andrews Coffee Shop
# 3  4b9fa61df964a520943137e3       FCB Coffee Bar
# 4  4ff2459fe4b0a148f89af102      Gregorys Coffee
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1588780820    False
# 1  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...  v-1588780820    False
# 2  [{'id': '4bf58dd8d48988d147941735', 'name': 'D...  v-1588780820    False
# 3  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1588780820    False
# 4  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1588780820    False
#
#              location.address  location.lat  location.lng  \
# 0                 40th Street     40.754242    -73.986532
# 1               116 W 32nd St     40.748753    -73.989755
# 2                 463 7th Ave     40.751499    -73.990182
# 3               100 W 33rd St     40.748792    -73.988575
# 4  874 Avenue of the Americas     40.747728    -73.989083
#
#                              location.labeledLatLngs  location.distance  ...  \
# 0  [{'label': 'display', 'lat': 40.754242, 'lng':...                612  ...
# 1  [{'label': 'display', 'lat': 40.74875252113379...                 59  ...
# 2  [{'label': 'display', 'lat': 40.75149915407228...                272  ...
# 3  [{'label': 'display', 'lat': 40.74879242943224...                 71  ...
# 4  [{'label': 'display', 'lat': 40.7477283, 'lng'...                159  ...
#
#                            location.formattedAddress delivery.id  \
# 0   [40th Street, New York, NY 10018, United States]     1961430
# 1  [116 W 32nd St (btwn 6th & 7th Ave), New York,...         NaN
# 2  [463 7th Ave (at W 35th St.), New York, NY 100...         NaN
# 3  [100 W 33rd St, New York, NY 10001, United Sta...         NaN
# 4  [874 Avenue of the Americas (at W 31st St), Ne...         NaN
#
#                                         delivery.url delivery.provider.name  \
# 0  https://www.seamless.com/menu/le-cafe-coffee-1...               seamless
# 1                                                NaN                    NaN
# 2                                                NaN                    NaN
# 3                                                NaN                    NaN
# 4                                                NaN                    NaN
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 1                                       NaN                          NaN
# 2                                       NaN                          NaN
# 3                                       NaN                          NaN
# 4                                       NaN                          NaN
#
#                 delivery.provider.icon.name location.crossStreet venuePage.id  \
# 0  /delivery_provider_seamless_20180129.png                  NaN          NaN
# 1                                       NaN   btwn 6th & 7th Ave          NaN
# 2                                       NaN        at W 35th St.     58938570
# 3                                       NaN                  NaN          NaN
# 4                                       NaN         at W 31st St          NaN
#
#   location.neighborhood
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Clean the data

# %%
#Use only relevant columns
dataframe = dataframe[['id','name','location.distance']]
dataframe.head()
# Out:
#                          id                 name  location.distance
# 0  5d03930e1c0b34002cd41e53       Le Cafe Coffee                612
# 1  4da4881522a5f04d67b03a55               Cafe R                 59
# 2  4bf5663994af2d7f15a93b72  Andrews Coffee Shop                272
# 3  4b9fa61df964a520943137e3       FCB Coffee Bar                 71
# 4  4ff2459fe4b0a148f89af102      Gregorys Coffee                159

# %%
#Remove rows with null values
dataframe.dropna()
# Out:
#                           id                                   name  \
# 0   5d03930e1c0b34002cd41e53                         Le Cafe Coffee
# 1   4da4881522a5f04d67b03a55                                 Cafe R
# 2   4bf5663994af2d7f15a93b72                    Andrews Coffee Shop
# 3   4b9fa61df964a520943137e3                         FCB Coffee Bar
# 4   4ff2459fe4b0a148f89af102                        Gregorys Coffee
# 5   4aa52d50f964a520834720e3              Stumptown Coffee Roasters
# 6   4c20b685132f0f47860ea796                 Coffee Bagel Roll Cart
# 7   50707408e4b0dc1abfeddd39                     Herald Square Café
# 8   4b6c8e66f964a520dc422ce3                        Cafe Rustico II
# 9   49e8b08bf964a5206c651fe3                           Captain Cafe
# 10  4b7578d6f964a5206b0e2ee3                                 Cafe M
# 11  4acea30ff964a52084d120e3                        Martinique Cafe
# 12  4b3a52ccf964a520a36425e3                    Best Bagel & Coffee
# 13  56229913498efe46cf97581f                        Gregorys Coffee
# 14  4ddecc7ad4c01aeee905c13b                                Cafe 28
# 15  4b3f797ff964a52077a725e3                 The Bread Factory Café
# 16  5304fa4a11d250deb2a90667                        Hanamizuki Cafe
# 17  4bdb964ec712b71350aa63b4                             Cafe Nunez
# 18  4c163ecaa9c220a1f34a5a9d              Café Bonjour Deli & Pizza
# 19  4b857711f964a520b05f31e3                               Cafe 498
# 20  4c6424c1de1b2d7fd875e670                            Europa Café
# 21  4c24b32cf7ced13a0b33236d                        Gregorys Coffee
# 22  4bb9dabc53649c74fd4c48fb               Coffee Cart 24th and 6th
# 23  546de728498ee355dde78545                          Coffee Corner
# 24  4bb51053ef159c74c33674f7                  Seattle's Best Coffee
# 25  4c220e6caa8e9c74e35ef4d4                   Ramin's Coffee Stand
# 26  591c50dba9e4021d1d8029a1                        Gregorys Coffee
# 27  449bd15bf964a520a4341fe3                          Think Cafe 32
# 28  4eb2ccbfd5fb935c32d16864            coffee cart 33rd & broadway
# 29  4b967b4ef964a520edce34e3                    Coffee & Donut Cart
# 30  49de8185f964a5205b601fe3                           Macaron Café
# 31  4b279ec7f964a520db8724e3                   Express Coffee Stand
# 32  4bb2048bf964a52050b23ce3               Coffee Cart 37th and 7th
# 33  4f4797a3e4b072f5a971dba0  Jerusalem Cafe (formerly Jerusalem 2)
# 34  4c63f11aec94a593d0eb2cca       W 39th St & Broadway Coffee Cart
# 35  5045f458e4b03986a68c25c6                            Coffee Cart
# 36  4ad79db1f964a520d20c21e3                          Favorite Cafe
# 37  5808c50438fab4f721071cb9               Empire State Coffee Cart
# 38  4c244400c9bbef3bb433afac              Coffee & Halal Food Truck
# 39  4e1c5c0b62e147e54f516cfd                Coffee Cart On Broadway
# 40  4b6c5ec9f964a52068342ce3                           Europan Cafe
# 41  5d4478afcf1f80000855abba                        LÜLÜ COFFEE CO.
# 42  53553434498e5d7727b4ae43               coffee cart 31st and 6th
# 43  4b37ec3cf964a520b74825e3                                 W Cafe
# 44  4e401f9ee4cdab9b9365895c                              Mars Cafe
# 45  4bba2942b35776b0209aca01                            Garden Cafe
# 46  5a09b45b6dcf043c23d5ad4e                   King’s Street Coffee
# 47  51789973e4b04c79990d1d00                          NY Study Cafe
# 48  59e618dc4c9be64fbe509006                          Patent Coffee
# 49  57f639adcd1040fbcdd592c7                     32 St Coffee  Cart
#
#     location.distance
# 0                 612
# 1                  59
# 2                 272
# 3                  71
# 4                 159
# 5                 382
# 6                  46
# 7                 164
# 8                 329
# 9                 477
# 10                410
# 11                137
# 12                368
# 13                309
# 14                527
# 15                318
# 16                288
# 17                396
# 18                525
# 19                408
# 20                231
# 21                574
# 22                371
# 23                310
# 24                259
# 25                358
# 26                485
# 27                187
# 28                103
# 29                387
# 30                319
# 31                338
# 32                425
# 33                341
# 34                517
# 35                544
# 36                471
# 37                109
# 38                600
# 39                179
# 40                351
# 41                217
# 42                166
# 43                463
# 44                545
# 45                287
# 46                189
# 47                403
# 48                442
# 49                150

# %%
#Add columns to dataframe to find reviews,and tips
import numpy as np
dataframe["Tips"]=np.nan
dataframe["MostFrequentAge"]=np.nan
dataframe.head()
# Out:
#                          id                 name  location.distance  Tips  \
# 0  5d03930e1c0b34002cd41e53       Le Cafe Coffee                612   NaN
# 1  4da4881522a5f04d67b03a55               Cafe R                 59   NaN
# 2  4bf5663994af2d7f15a93b72  Andrews Coffee Shop                272   NaN
# 3  4b9fa61df964a520943137e3       FCB Coffee Bar                 71   NaN
# 4  4ff2459fe4b0a148f89af102      Gregorys Coffee                159   NaN
#
#    MostFrequentAge
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
#For each venue id, get the tips
for index,row in dataframe.iterrows():
    venue_id=row['id']
    url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, 1)
    results = requests.get(url).json()
    print(results)
    tips = results['response']['tips']['items']
    print(row['name'])
    print("Tips\n",tips)
# Out:
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5eb2dd35dd0f85001b3ab0f0'}, 'response': {}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-d108e81c8dd8> in <module>
#       5     results = requests.get(url).json()
#       6     print(results)
# ----> 7     tips = results['response']['tips']['items']
#       8     print(row['name'])
#       9     print("Tips\n",tips)
#
# KeyError: 'tips'

# %% [markdown]
# **Since I am only able to access two tips per day total via the api, and not able to get demographic stats, I decided to mock them**

# %%
from random import randint, choice
mock_tips=('Good music','great food', 'quiet', 'bad service','quick service','authentic coffee','original brews', 'family fun', 'work atmosphere')
df_tips =[] #to be added to the dataframe
df_age=[] #To be added to data frame
num_rows = len(dataframe.index)
for i in range(0,num_rows):
    df_tips.append(choice(mock_tips))
    temp_age=randint(10,91)
    df_age.append(temp_age-(temp_age%10)) #generate a random age groups binned into 10s from 10 to 90
    
dataframe.drop('Tips',axis=1,inplace=True)
dataframe.drop('MostFrequentAge',axis=1,inplace=True)
dataframe['tips']=df_tips
dataframe['Age']=df_age

# %%
dataframe.head()
# Out:
#                          id                 name  location.distance  \
# 0  5d03930e1c0b34002cd41e53       Le Cafe Coffee                612
# 1  4da4881522a5f04d67b03a55               Cafe R                 59
# 2  4bf5663994af2d7f15a93b72  Andrews Coffee Shop                272
# 3  4b9fa61df964a520943137e3       FCB Coffee Bar                 71
# 4  4ff2459fe4b0a148f89af102      Gregorys Coffee                159
#
#                tips  Age
# 0   work atmosphere   40
# 1        Good music   70
# 2       bad service   10
# 3  authentic coffee   80
# 4             quiet   20

# %% [markdown]
# # Data analytics
# Now we can begin running different algorithms such as KNN to reccomend something based on tips and age.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
#Preprocess data
X = dataframe[['tips', 'Age']].values
Y = dataframe['name']
X[0]
le_tips = preprocessing.LabelEncoder()
le_tips.fit(mock_tips)
X[:,0] = le_tips.transform(X[:,0])

# %%
reccomender = DecisionTreeClassifier(criterion="entropy", max_depth = 4)
reccomender.fit(X,Y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=4, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %% [markdown]
# **Finally, reccomend a place to the user**

# %%
le_name_mapping = dict(zip(le_tips.classes_, le_tips.transform(le_tips.classes_)))
le_name_mapping
processed_user_pref=le_name_mapping.get(user_Preference,0)
reccomendation = reccomender.predict([[processed_user_pref,user_Age]])

# %% [markdown]
# **This finally gives us a reccomendation of**

# %%
reccomendation[0]
# Out:
# 'Garden Cafe'
